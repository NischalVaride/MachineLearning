# %%
######Needed Imports ##################
import numpy as np
import pandas as pd
import matplotlib as mp
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading the CSV
df = pd.read_csv('Iris.csv')

# %%
#Making Sure that All Rows and Columns are Displayed at the same time not setting the max_row to max Number
pd.set_option.max_row = df.shape[0]
pd.set_option.max_columns = df.shape[1]

# %%
df.head()
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa

# %%
df.columns
# Out:
# Index(['Sepal Length (in cm)', 'Sepal Width in (cm)', 'Petal length (in cm)',
#        'Petal width (in cm)', 'Class'],
#       dtype='object')

# %%
#There are No Missing Values Here
df.isnull().sum()
# Out:
# Sepal Length (in cm)    0
# Sepal Width in (cm)     0
# Petal length (in cm)    0
# Petal width (in cm)     0
# Class                   0
# dtype: int64

# %%
#All Types Looks fine 
df.dtypes
# Out:
# Sepal Length (in cm)    float64
# Sepal Width in (cm)     float64
# Petal length (in cm)    float64
# Petal width (in cm)     float64
# Class                    object
# dtype: object

# %%
#Printing 10 frames from the bottom
df[140:]
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# ...

# %%
#Printing 10 frame from the bottom when we dont know the shape of data frame
df[-10:]
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# ...

# %%
#Set the Index of Dataframe to be first Column
df.set_index(df.columns[0])
# Out:
#                       Sepal Width in (cm)  Petal length (in cm)  \
# Sepal Length (in cm)
# 5.1                                   3.5                   1.4
# 4.9                                   3.0                   1.4
# 4.7                                   3.2                   1.3
# 4.6                                   3.1                   1.5
# 5.0                                   3.6                   1.4
# 5.4                                   3.9                   1.7
# 4.6                                   3.4                   1.4
# 5.0                                   3.4                   1.5
# 4.4                                   2.9                   1.4
# 4.9                                   3.1                   1.5
# 5.4                                   3.7                   1.5
# 4.8                                   3.4                   1.6
# 4.8                                   3.0                   1.4
# ...

# %%
#Use iloc function to print all the rows of the 3rd column
df.iloc[:,(3-1)]
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
# 5      1.7
# 6      1.4
# 7      1.5
# 8      1.4
# 9      1.5
# 10     1.5
# 11     1.6
# 12     1.4
# 13     1.1
# 14     1.2
# 15     1.5
# 16     1.3
# 17     1.4
# 18     1.7
# 19     1.5
# 20     1.7
# 21     1.5
# 22     1.0
# 23     1.7
# 24     1.9
# 25     1.6
# 26     1.6
# 27     1.5
# 28     1.4
# 29     1.6
#       ...
# 120    5.7
# 121    4.9
# 122    6.7
# 123    4.9
# 124    5.7
# 125    6.0
# 126    4.8
# 127    4.9
# 128    5.6
# 129    5.8
# 130    6.1
# 131    6.4
# 132    5.6
# 133    5.1
# 134    5.6
# 135    6.1
# 136    5.6
# 137    5.5
# 138    4.8
# 139    5.4
# 140    5.6
# 141    5.1
# 142    5.1
# 143    5.9
# 144    5.7
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: Petal length (in cm), Length: 150, dtype: float64

# %%
#Display all columns of 3rd Row
df.iloc[3:4,:]
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 3                   4.6                  3.1                   1.5
#
#    Petal width (in cm)        Class
# 3                  0.2  Iris-setosa

# %%
#Print only the Sepal width and Sepal Length for first 10 rows
#df.loc[0:10, ['Sepal Length (in cm)', 'Sepal Width in (cm)']]
df.loc[0:10,list(df.columns[0:2])]
# Out:
#     Sepal Length (in cm)  Sepal Width in (cm)
# 0                    5.1                  3.5
# 1                    4.9                  3.0
# 2                    4.7                  3.2
# 3                    4.6                  3.1
# 4                    5.0                  3.6
# 5                    5.4                  3.9
# 6                    4.6                  3.4
# 7                    5.0                  3.4
# 8                    4.4                  2.9
# 9                    4.9                  3.1
# 10                   5.4                  3.7

# %%
#Print all the columns of row which has class name "Iris-setosa"
df.loc[df['Class'] == 'Iris-setosa', :]
# Out:
#     Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                    5.1                  3.5                   1.4
# 1                    4.9                  3.0                   1.4
# 2                    4.7                  3.2                   1.3
# 3                    4.6                  3.1                   1.5
# 4                    5.0                  3.6                   1.4
# 5                    5.4                  3.9                   1.7
# 6                    4.6                  3.4                   1.4
# 7                    5.0                  3.4                   1.5
# 8                    4.4                  2.9                   1.4
# 9                    4.9                  3.1                   1.5
# 10                   5.4                  3.7                   1.5
# 11                   4.8                  3.4                   1.6
# 12                   4.8                  3.0                   1.4
# ...

# %%
#Print all the columns of row which has class name "Iris-setosa"(Using groupby :) 
df.groupby('Class').get_group('Iris-setosa')
# Out:
#     Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                    5.1                  3.5                   1.4
# 1                    4.9                  3.0                   1.4
# 2                    4.7                  3.2                   1.3
# 3                    4.6                  3.1                   1.5
# 4                    5.0                  3.6                   1.4
# 5                    5.4                  3.9                   1.7
# 6                    4.6                  3.4                   1.4
# 7                    5.0                  3.4                   1.5
# 8                    4.4                  2.9                   1.4
# 9                    4.9                  3.1                   1.5
# 10                   5.4                  3.7                   1.5
# 11                   4.8                  3.4                   1.6
# 12                   4.8                  3.0                   1.4
# ...

# %%
##Find out the mean and variance for each column but for class column(Method1)

#df[df.columns[0]].describe()
#df[df.columns[0]].mean()
df[df.columns[0]].var()
# Out:
# 0.6856935123042505

# %%
#df[df.columns[1]].describe()
#df[df.columns[1]].mean()
df[df.columns[1]].var()
# Out:
# 0.18800402684563763

# %%
#df[df.columns[2]].describe()
#df[df.columns[2]].mean()
df[df.columns[2]].var()
# Out:
# 3.1131794183445156

# %%
#df[df.columns[3]].describe()
#df[df.columns[3]].mean()
df[df.columns[3]].var()
# Out:
# 0.5824143176733784

# %%
### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
def function(x):
    sepal_length, sepal_width = x
    print(sepal_length)
    print(sepal_width)

# %%
df.loc[5:5, [df.columns[0], df.columns[1]]].apply(function, axis=1)
# Out:
# 5.4
# 3.9
# 5    None
# dtype: object

# %%
#Find the range of all the columns in the dataset

# %%
#df[df.columns[0]].max() - df[df.columns[0]].min()
df[df.columns[0]].describe()['max'] - df[df.columns[0]].describe()['min']
# Out:
# 3.6000000000000005

# %%
#df[df.columns[1]].max() - df[df.columns[1]].min()
df[df.columns[1]].describe()['max'] - df[df.columns[1]].describe()['min']
# Out:
# 2.4000000000000004

# %%
#df[df.columns[2]].max() - df[df.columns[2]].min()
df[df.columns[2]].describe()['max'] - df[df.columns[2]].describe()['min']
# Out:
# 5.9

# %%
#df[df.columns[3]].max() - df[df.columns[3]].min()
df[df.columns[3]].describe()['max'] - df[df.columns[3]].describe()['min']
# Out:
# 2.4

# %%
#Sort Entries dataset according to Column Petal Width

# %%
df.sort_values(by=['Petal width (in cm)'])
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 32                    5.2                  4.1                   1.5
# 13                    4.3                  3.0                   1.1
# 37                    4.9                  3.1                   1.5
# 9                     4.9                  3.1                   1.5
# 12                    4.8                  3.0                   1.4
# 34                    4.9                  3.1                   1.5
# 46                    5.1                  3.8                   1.6
# 42                    4.4                  3.2                   1.3
# 39                    5.1                  3.4                   1.5
# 38                    4.4                  3.0                   1.3
# 36                    5.5                  3.5                   1.3
# 33                    5.5                  4.2                   1.4
# 28                    5.2                  3.4                   1.4
# ...

# %%
#Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
df['SepalExtra'] = df[df.columns[0]] * df[df.columns[1]]

# %%
df[0:2]
# Out:
#     Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 32                   5.2                  4.1                   1.5
# 13                   4.3                  3.0                   1.1
#
#     Petal width (in cm)        Class  SepalExtra
# 32                  0.1  Iris-setosa       21.32
# 13                  0.1  Iris-setosa       12.90

# %%
###Remove the new column "SepalExtra" from the dataframe¶
del(df['SepalExtra'])

# %%
df[0:2]
# Out:
#     Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 32                   5.2                  4.1                   1.5
# 13                   4.3                  3.0                   1.1
#
#     Petal width (in cm)        Class
# 32                  0.1  Iris-setosa
# 13                  0.1  Iris-setosa

# %%
#Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
irisSubset = df[0:10][[df.columns[0], df.columns[1], df.columns[2]]]

# %%
type(irisSubset)
# Out:
# pandas.core.frame.DataFrame

# %%
irisSubset.head()
# Out:
#     Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)
# 32                   5.2                  4.1                   1.5
# 13                   4.3                  3.0                   1.1
# 37                   4.9                  3.1                   1.5
# 9                    4.9                  3.1                   1.5
# 12                   4.8                  3.0                   1.4

# %%
###############################################PART 2 #################################################################

# %%
#######################################################################################################################

# %%
#Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters
df = pd.read_csv("HR.txt", sep="\t")

# %%
#Making Sure that All Rows and Columns are Displayed at the same time not setting the max_row to max Number
pd.set_option.max_row = df.shape[0]
pd.set_option.max_columns = df.shape[1]

# %%
df.head()
# Out:
#   Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0        Ind1       Yes   41               1       1102           1
# 1        Ind2        No   49               2        279           2
# 2        Ind3       Yes   37               1       1373           2
# 3        Ind4        No   33               2       1392           2
# 4        Ind5        No   27               1        591           2
#
#    DistanceFromHome  Education  EducationField  EmployeeCount  ...  \
# 0                 1          2               1              1  ...
# 1                 8          1               1              1  ...
# 2                 2          2               6              1  ...
# 3                 3          4               1              1  ...
# 4                 2          1               2              1  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             80                 0
# ...

# %%
#No of Rows
df.shape[0]
# Out:
# 1470

# %%
#No of Columns
df.shape[1]
# Out:
# 35

# %%
#Find out the type of Each and Every Column in the Dataset

# %%
df.dtypes
# Out:
# Individual                  object
# Attrition                   object
# Age                          int64
# BusinessTravel               int64
# DailyRate                    int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                       int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                      int64
# JobSatisfaction              int64
# MaritalStatus                int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                     int64
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
#Print All Rows from 3rd Column to 10th Column

# %%
df.iloc[:, 3:10]
# Out:
#       BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0                  1       1102           1                 1          2
# 1                  2        279           2                 8          1
# 2                  1       1373           2                 2          2
# 3                  2       1392           2                 3          4
# 4                  1        591           2                 2          1
# 5                  2       1005           2                 2          2
# 6                  1       1324           2                 3          3
# 7                  1       1358           2                24          1
# 8                  2        216           2                23          3
# 9                  1       1299           2                27          3
# 10                 1        809           2                16          3
# 11                 1        153           2                15          2
# ...

# %%
#Find out the IQR for the column - Age

# %%
df['Age'].describe()['75%'] - df['Age'].describe()['25%']
# Out:
# 13.0

# %%
#Find out the mean, median and variance for the column - DailyRate

# %%
df['DailyRate'].mean()
# Out:
# 802.4857142857143

# %%
df['DailyRate'].median()
# Out:
# 802.0

# %%
df['DailyRate'].var()
# Out:
# 162819.59373723628

# %%
##############Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)########

# %%
sns.distplot(df['Attrition'].apply(lambda x: 1 if(x=='Yes') else 0), rug=True, kde=True)

# %%
df['TotalWorkingYears'].value_counts()
# Out:
# 10    202
# 6     125
# 8     103
# 9      96
# 5      88
# 1      81
# 7      81
# 4      63
# 12     48
# 3      42
# 15     40
# 16     37
# 13     36
# 11     36
# 21     34
# 17     33
# 14     31
# 2      31
# 20     30
# 18     27
# 19     22
# 23     22
# 22     21
# 24     18
# 25     14
# 28     14
# 26     14
# 0      11
# 29     10
# 31      9
# 32      9
# 27      7
# 30      7
# 33      7
# 36      6
# 34      5
# 37      4
# 35      3
# 40      2
# 38      1
# Name: TotalWorkingYears, dtype: int64

# %%
###########################Plot Total working years using matplotlib plot function##########################

# %%
import datetime

# %%
#Just want to find out the Time frame when the Person Joined the Office
plt.plot(df['TotalWorkingYears'],(datetime.date.today().year - df['TotalWorkingYears']))

# %%
vp = plt.violinplot(df['TotalWorkingYears'], showmedians=True)

# %%
sns.distplot(df['TotalWorkingYears'], rug=True, kde=True)
